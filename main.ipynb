# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

uae = pd.read_csv("dubai_properties.csv")

dubai = uae[uae['City'] == 'Dubai']

# %%
from process_location_averages import process_location_averages
df = process_location_averages("dubai_properties.csv")
df_sorted = df.sort_values(by="Avg_Rent_per_sqft", ascending=False)
df_sorted
# Out:
#               Location   Latitude  Longitude  Avg_Rent_per_sqft  \
# 35   Bluewaters Island  25.082916  55.122156         329.640937
# 107     Pearl Jumeirah  25.244474  55.258960         232.609087
# 50       Dubai Harbour  25.095619  55.138001         226.933742
# 47      Downtown Dubai  25.186684  55.274705         199.156925
# 83    Jumeirah Islands  25.057059  55.156146         196.578116
# ..                 ...        ...        ...                ...
# 66    Dubai Waterfront  24.944817  54.998449          46.803540
# 13        Al Khawaneej  25.238252  55.509796          33.605870
# 134     Wadi Al Shabak  25.175974  55.478478          30.028006
# 0              Al Awir  25.177447  55.569534          25.372372
# 17           Al Mizhar  25.245084  55.450315          23.868297
#
#      Properties_Count
# 35                192
# 107                 7
# 50                460
# 47               3003
# 83                 68
# ..                ...
# 66                 13
# ...
