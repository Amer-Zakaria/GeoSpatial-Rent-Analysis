# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

uae = pd.read_csv("dubai_properties.csv")

dubai = uae[uae['City'] == 'Dubai']

# %%
dubai.groupby("Type").size()
# Out:
# Type
# Apartment               26155
# Hotel Apartment           450
# Penthouse                 153
# Residential Building       11
# Residential Floor          10
# Residential Plot            2
# Townhouse                2358
# Villa                    5094
# Villa Compound             17
# dtype: int64
